# %% [markdown]
# <a href="https://colab.research.google.com/github/mesogin/TIS2/blob/main/2_%EB%8B%A4%EC%96%91%ED%95%9C_%EA%B7%B8%EB%9E%98%ED%94%84_%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #다양한 그래프 그리기

# %%
# 시각화 패키지 seaborn, matplotlib 불러오기

import seaborn as sns
from matplotlib import pyplot as plt

sns.set()
# %matplotlib inline

# %%
# 한글폰트 사용 in colab
# %matplotlib inline  

import matplotlib as mpl 
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm

# 한글폰트 다운로드
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf' 
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
# 마이너스 깨짐 현상 방지
mpl.rcParams['axes.unicode_minus'] = False
# Out:
# NanumBarunGothic

# %% [markdown]
# **(📌 주의)** 이 단계에서 **런타임 - 런타임 다시 시작** 을 클릭하여 런타임을 재시작해야 합니다.

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ##선 스타일 및 두께 설정
# ###선 스타일
# solid (기본값)
# dashed
# dotted
# dashdot
# ### 선 두께
# linewidth 인자로 설정(기본값 1.5)

# %%
plt.plot([1,2,3], [4,1,2], linestyle="dashed", label = "점선(긴선)")
plt.plot([1,2,3], [5,6,0], linestyle="dotted", label = "점선")
plt.plot([1,2,3], [1,2,3], linestyle="dashdot", label = "점선, 긴선")
plt.plot([1,2,3], [4,5,2], linestyle="solid", label = "실선")
plt.legend(loc = "upper right")

# %% [markdown]
# ### 마커 (marker)설정
# 데이터 포인트를 표시하는 marker를 설정할 수 있습니다.
# - "." : (점)
# - "O" : (원)
# - "s" : (사각형)
# - "*" : (별)
# - "D" : (다이아몬드)
# - "d" : (홀쭉한 다이아몬드) 등
#
# ### 사이즈
# - markersize 인자로 설정

# %%
# 크기가 10이고 별인 마커와 크기가 8인 원형인 마커 사용

plt.plot([1,2,3], [4,1,2], marker = "*", markersize = "10", label = "line1")
plt.plot([1,2,3], [5,6,0], marker = "o", markersize = "8", label = "line2")
plt.legend(loc = "upper right")

# %%
#산점도 설정
import numpy as np
x = np.random.normal(0, 1, 10000)
y = np.random.normal(0, 1, 10000)

#투명도 설정
plt.scatter(x,y, alpha = 0.05)

# %%
#연습문제 (산점도 그리기)
#평균 10, 분산이 5인 난수 (난수의 개수 : 100,000개) 배열을 2개 생성하여 각각을 x좌표와 y좌표로 설정
#점들이 너무 뭉치지 않도록 배려하시오.

import numpy as np
plt.title("산점도 10만개 찍어보기") #제목설정
x = np.random.normal(10, 5, 100000)
y = np.random.normal(10, 5, 100000)

plt.scatter(x,y, alpha = 0.02)

# %%
#막대 그래프
# 0,1,2 위치에 각각 높이가 10, 20, 30인 막대

plt.bar(range(3), [10, 20, 30])  #막대 높이
plt.xticks(range(3), ["A", "B", "C"])  # 막대 눈금값 설정
# Out:
# ([<matplotlib.axis.XTick at 0x7fed4f55c820>,
# ...
#  [Text(0, 0, 'A'), Text(0, 0, 'B'), Text(0, 0, 'C')])

# %% [markdown]
# ###스타일 설정
# width, color, linewidth 등의 인자로 두꼐 생상 선 두께 등의 스타일 설정가능하다.

# %%
plt.bar(range(3), [10, 20,30], width=0.5, color=["orange", "blue", "green"], linewidth=3.5)
plt.xticks(range(3), ["A", "B", "C"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fed4f59ddc0>,
# ...
#  [Text(0, 0, 'A'), Text(0, 0, 'B'), Text(0, 0, 'C')])

# %% [markdown]
# # 박스 플롯
#
# **박스플롯(boxplot)**은 **데이터의 통계량과 이상치(outlier)**를 한 눈에 볼 수 있는 그래프입니다.
#
# [그림: 박스플롯](https://docs.google.com/presentation/d/147FrGk2E0B0rDibuqmPYlq8UpJyjblG3E7Vzw_px_u0/edit?usp=sharing)
#
# [설명: 박스플롯](https://blog.naver.com/nabilera1/222991004424)
#
#
#
#  그림에서 **위쪽에 있는 수염**은 (Q3 + 1.5 * (Q3-Q1))를, **아래쪽에 있는 수염**은 (Q1 - 1.5 * (Q3-Q1))를 나타내며, **이상치**는 이 기준을 벗어나는 데이터 포인트를 의미합니다.
#
#  맷플롯립에서 박스플롯은 **boxplot**이라는 함수를 이용해서 그립니다. 이 함수는 박스플롯을 그릴 때 배열을 입력으로 받습니다. 1차원 배열을 입력하면 그 배열로 박스를 그리며, 2차원 배열을 입력하면 요소마다 하나의 박스를 그립니다.

# %%
x1 = np.random.normal(10, 5, 1000)
x2 = np.random.normal(10, 10, 100)
plt.boxplot([x1, x2])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
#히스토그램
#도수분포표를 시각화한 것으로 변수의 분포를 확인하는데 적절한 시각화 방법이다. hist()함수 사용
x = np.random.normal(10, 2, 100) #평균10 분포2 100개생성
plt.hist(x)
plt.show()

# %%
#구간 나누기
plt.hist(x, bins = 20)
plt.show()

# %%
#히트맵
# 예제에 사용할 데이터

import pandas as pd

data  = pd.DataFrame({"수학":[100, 80, 90], "영어":[70,90,80]},
                     index=["철수", "영희", "민수"])
display(data)

# 히트맵 그리기
import seaborn as sns
sns.heatmap(data)
# Out:
#      수학  영어
# 철수  100  70
# 영희   80  90
# 민수   90  80

# %%
#눈금값 설정
#행과 열 인덱스가 따로 없는 중첩배열이 입력되면 x축,y축의 눈금값을 직접 설정해야함
sns.heatmap(data)
plt.xticks([0.5, 1.5], ["수학", "영어"])
plt.yticks([0.5, 1.5, 2.5], ["철수", "영희", "민수"])

# %%
#데이터 표시
#annot 인자를 True로 설정하면 박스와 대응되는 데이터가 표시됩니다. (fmt 인자를 데이터를 어떻게 표현할지 설정)
sns.heatmap(data, annot = True, fmt= ".2f")  #데이터표시, 소수점 2자리수까지

# %%
#선 스타일 설정
#두께와 색상은 linewidths와 linecolor 인자를 사용해서 설정함
sns.heatmap(data, annot = True, fmt= ".2f", linewidth=1, linecolor="black")

# %%
#컬러맵 설정
#색상 변경 cmap 인자 사용
sns.heatmap(data, annot = True, fmt= ".2f", 
            cmap="Reds", linewidth=1, linecolor="white")

# %% [markdown]
# [미 증시 히트맵 참고자료](https://finviz.com/map.ashx)
